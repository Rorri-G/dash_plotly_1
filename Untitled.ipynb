# %%
import pandas as pd

# %%
df = pd.read_csv(
    '/Users/biorgan/Development/development/dash_plot_proyetc/Covid19VacunasEcuador.csv')

# %%
df.head()
# Out:
#    zona  region  provincia  poblacion  dosis_total  primera_dosis  \
# 0     8   costa     Guayas    4387434      6438651        3298003
# 1     9  sierra  Pichincha    3228233      5804701        2770181
# 2     4   costa     Manabí    1562079      2548773        1292541
# 3     6  sierra      Azuay     881394      1464203         708476
# 4     5   costa   Los Ríos     921763      1255473         664812
#
#    segunda_dosis  dosis_unica  dosis_refuerzo       lat        lng  created_at
# 0        2843199        94033          203416 -2.183333 -79.883333  01/01/2022
# 1        2651332        57413          325775 -0.218611 -78.509722  01/01/2022
# 2        1137831        50651           67750 -1.056181 -80.455217  01/01/2022
# 3         659683        16102           79942 -2.897414 -79.004481  01/01/2022
# 4         532889        26565           31207 -1.800000 -79.533333  01/01/2022
